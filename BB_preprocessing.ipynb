# %%
import import_ipynb

# %%
from AA_eda import *
# Out:
#         id full_name   age      gender device_type ad_position  \
# 68    1524  User1524  24.0         NaN      Mobile      Bottom
# 86    3266  User3266   NaN        Male      Tablet         Top
# 141   6315  User6315   NaN         NaN     Desktop         Top
# 211   4086  User4086   NaN      Female     Desktop         Top
# 212   9400  User9400   NaN  Non-Binary      Mobile        Side
# ...    ...       ...   ...         ...         ...         ...
# 9981  7808  User7808  26.0      Female     Desktop         Top
# 9984  9422  User9422  21.0         NaN         NaN        Side
# 9985  8994  User8994  34.0         NaN      Mobile      Bottom
# 9986  5574  User5574  52.0      Female     Desktop      Bottom
# 9992  5818  User5818   NaN         NaN      Tablet         Top
#
#      browsing_history time_of_day  click
# 68                NaN       Night      1
# 86               News   Afternoon      1
# 141               NaN   Afternoon      1
# 211     Entertainment     Morning      1
# ...
